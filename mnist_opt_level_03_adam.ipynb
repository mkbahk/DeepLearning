# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from keras import regularizers

# %%
#하이퍼 파라메터 정의(매개변수들)
EPOCHS = 200
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 #출력갯수 = 숫자의 갯수
N_HIDDEN = 128 
VALIDATION_SPLIT = 0.2 #검증을 위해 남겨둘 훈련 데이타
DROPOUT = 0.3

# %%
# MNIST 데이타셋 로드(MNIST는 숫자만, eMNIST는 숫자+알파벳, 패션MNIST는 옷그림들이 있다)
# X값 훈련용, 테스트 데이터를 각각 60,000개와 10,000개로 나눈다
# 레이블(정답, Y값)에 대한 원핫 인코딩을 자동으로 적용한다
# 아래 데이타셋을 .png 형태의 이미지를 이미 숫자화한 배열형태로 바꾸어 놓은 것이며, .csv형태가 분석 초기 데이타이다.
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# X_train은 60,000개 행으로 28x28 값을 가진다. 이를 60,000 x 784(28x28)의 행렬형태로 변환한다.
RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# 입력을 [0, 1] 사이로 정규화
X_train /= 255.0
X_train /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'train samples')

# 레이블을 원한 엔코딩, 그래야 행렬 연산이 가능함
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)
# Out:
# 60000 train samples
# 10000 train samples

# %%
# 모델 구축(정의)
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_Dense_layer_1', activation='relu', kernel_regularizer=regularizers.l2(0.01),
                activity_regularizer=regularizers.l1(0.01)))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_Dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_Dense_layer_3', activation='softmax'))

# %%
# 모델 컴파일
model.compile(optimizer='Adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# 모델 형태 보기
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_Dense_layer_1 (Dense)  (None, 128)               100480
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# hidden_Dense_layer_2 (Dense) (None, 128)               16512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_Dense_layer_3 (Dense) (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 훈련
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(patience=15, mode='auto', monitor='val_accuracy')

hist = model.fit(x = X_train, y = Y_train, 
          batch_size = BATCH_SIZE, epochs=EPOCHS,
          verbose=VERBOSE, validation_split=VALIDATION_SPLIT,
          callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 375/375 [==============================] - 1s 3ms/step - loss: 2.3869 - accuracy: 0.1665 - val_loss: 2.0080 - val_accuracy: 0.2948
# Epoch 2/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.7862 - accuracy: 0.3833 - val_loss: 1.5771 - val_accuracy: 0.4834
# Epoch 3/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5515 - accuracy: 0.4612 - val_loss: 1.4020 - val_accuracy: 0.5397
# Epoch 4/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4401 - accuracy: 0.5203 - val_loss: 1.2795 - val_accuracy: 0.6316
# Epoch 5/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3574 - accuracy: 0.5671 - val_loss: 1.1969 - val_accuracy: 0.6710
# Epoch 6/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2850 - accuracy: 0.6130 - val_loss: 1.1169 - val_accuracy: 0.7131
# Epoch 7/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2201 - accuracy: 0.6484 - val_loss: 1.0333 - val_accuracy: 0.7763
# Epoch 8/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.1479 - accuracy: 0.6795 - val_loss: 0.9553 - val_accuracy: 0.7928
# Epoch 9/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0851 - accuracy: 0.7076 - val_loss: 0.8769 - val_accuracy: 0.8205
# Epoch 10/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0248 - accuracy: 0.7311 - val_loss: 0.8338 - val_accuracy: 0.8357
# Epoch 11/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9714 - accuracy: 0.7487 - val_loss: 0.7715 - val_accuracy: 0.8501
# Epoch 12/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9363 - accuracy: 0.7640 - val_loss: 0.7405 - val_accuracy: 0.8621
# Epoch 13/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9017 - accuracy: 0.7721 - val_loss: 0.7015 - val_accuracy: 0.8664
# Epoch 14/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8761 - accuracy: 0.7839 - val_loss: 0.6826 - val_accuracy: 0.8622
# Epoch 15/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8540 - accuracy: 0.7891 - val_loss: 0.6846 - val_accuracy: 0.8640
# Epoch 16/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8329 - accuracy: 0.7943 - val_loss: 0.6279 - val_accuracy: 0.8802
# Epoch 17/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8044 - accuracy: 0.8021 - val_loss: 0.6223 - val_accuracy: 0.8798
# Epoch 18/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7888 - accuracy: 0.8075 - val_loss: 0.6005 - val_accuracy: 0.8825
# Epoch 19/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7767 - accuracy: 0.8113 - val_loss: 0.6310 - val_accuracy: 0.8656
# Epoch 20/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7582 - accuracy: 0.8150 - val_loss: 0.5630 - val_accuracy: 0.8897
# Epoch 21/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7483 - accuracy: 0.8191 - val_loss: 0.5968 - val_accuracy: 0.8813
# Epoch 22/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7388 - accuracy: 0.8203 - val_loss: 0.5654 - val_accuracy: 0.8821
# Epoch 23/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7250 - accuracy: 0.8258 - val_loss: 0.5529 - val_accuracy: 0.8854
# Epoch 24/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7063 - accuracy: 0.8286 - val_loss: 0.5356 - val_accuracy: 0.8978
# Epoch 25/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6940 - accuracy: 0.8314 - val_loss: 0.5043 - val_accuracy: 0.9029
# Epoch 26/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6895 - accuracy: 0.8325 - val_loss: 0.5280 - val_accuracy: 0.8978
# Epoch 27/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6750 - accuracy: 0.8377 - val_loss: 0.4911 - val_accuracy: 0.9038
# Epoch 28/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6665 - accuracy: 0.8388 - val_loss: 0.4911 - val_accuracy: 0.9028
# Epoch 29/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6708 - accuracy: 0.8388 - val_loss: 0.4724 - val_accuracy: 0.9097
# Epoch 30/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6497 - accuracy: 0.8446 - val_loss: 0.4684 - val_accuracy: 0.9102
# Epoch 31/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6483 - accuracy: 0.8428 - val_loss: 0.4638 - val_accuracy: 0.9135
# Epoch 32/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6512 - accuracy: 0.8421 - val_loss: 0.4764 - val_accuracy: 0.9083
# Epoch 33/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6281 - accuracy: 0.8500 - val_loss: 0.4589 - val_accuracy: 0.9130
# Epoch 34/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6194 - accuracy: 0.8526 - val_loss: 0.4412 - val_accuracy: 0.9152
# Epoch 35/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6238 - accuracy: 0.8503 - val_loss: 0.4475 - val_accuracy: 0.9097
# Epoch 36/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6118 - accuracy: 0.8518 - val_loss: 0.4449 - val_accuracy: 0.9134
# Epoch 37/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6077 - accuracy: 0.8546 - val_loss: 0.4437 - val_accuracy: 0.9099
# Epoch 38/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6037 - accuracy: 0.8557 - val_loss: 0.4256 - val_accuracy: 0.9151
# Epoch 39/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.6020 - accuracy: 0.8546 - val_loss: 0.4147 - val_accuracy: 0.9225
# Epoch 40/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5947 - accuracy: 0.8570 - val_loss: 0.4131 - val_accuracy: 0.9194
# Epoch 41/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5908 - accuracy: 0.8582 - val_loss: 0.4304 - val_accuracy: 0.9147
# Epoch 42/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5911 - accuracy: 0.8598 - val_loss: 0.4167 - val_accuracy: 0.9187
# Epoch 43/200
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5879 - accuracy: 0.8563 - val_loss: 0.4416 - val_accuracy: 0.9087
# Epoch 44/200
# 375/375 [==============================] - 1s 4ms/step - loss: 0.5838 - accuracy: 0.8595 - val_loss: 0.4253 - val_accuracy: 0.9177
# Epoch 45/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5850 - accuracy: 0.8594 - val_loss: 0.3907 - val_accuracy: 0.9238
# Epoch 46/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5847 - accuracy: 0.8566 - val_loss: 0.4003 - val_accuracy: 0.9237
# Epoch 47/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5812 - accuracy: 0.8591 - val_loss: 0.4332 - val_accuracy: 0.9099
# Epoch 48/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5761 - accuracy: 0.8606 - val_loss: 0.3963 - val_accuracy: 0.9221
# Epoch 49/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5822 - accuracy: 0.8590 - val_loss: 0.4054 - val_accuracy: 0.9185
# Epoch 50/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5834 - accuracy: 0.8593 - val_loss: 0.4017 - val_accuracy: 0.9199
# Epoch 51/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5641 - accuracy: 0.8626 - val_loss: 0.3922 - val_accuracy: 0.9238
# Epoch 52/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5703 - accuracy: 0.8607 - val_loss: 0.4017 - val_accuracy: 0.9162
# Epoch 53/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5723 - accuracy: 0.8627 - val_loss: 0.3832 - val_accuracy: 0.9257
# Epoch 54/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5675 - accuracy: 0.8615 - val_loss: 0.4463 - val_accuracy: 0.9032
# Epoch 55/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5713 - accuracy: 0.8609 - val_loss: 0.3815 - val_accuracy: 0.9269
# Epoch 56/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5748 - accuracy: 0.8606 - val_loss: 0.4113 - val_accuracy: 0.9120
# Epoch 57/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5756 - accuracy: 0.8582 - val_loss: 0.4087 - val_accuracy: 0.9158
# Epoch 58/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5680 - accuracy: 0.8611 - val_loss: 0.3976 - val_accuracy: 0.9200
# Epoch 59/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5639 - accuracy: 0.8633 - val_loss: 0.3846 - val_accuracy: 0.9252
# Epoch 60/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5594 - accuracy: 0.8642 - val_loss: 0.3764 - val_accuracy: 0.9270
# Epoch 61/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5538 - accuracy: 0.8648 - val_loss: 0.3703 - val_accuracy: 0.9293
# Epoch 62/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5577 - accuracy: 0.8647 - val_loss: 0.3714 - val_accuracy: 0.9282
# Epoch 63/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5478 - accuracy: 0.8661 - val_loss: 0.3680 - val_accuracy: 0.9242
# Epoch 64/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5548 - accuracy: 0.8655 - val_loss: 0.3672 - val_accuracy: 0.9289
# Epoch 65/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5569 - accuracy: 0.8650 - val_loss: 0.3840 - val_accuracy: 0.9205
# Epoch 66/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5555 - accuracy: 0.8634 - val_loss: 0.3914 - val_accuracy: 0.9213
# Epoch 67/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5791 - accuracy: 0.8564 - val_loss: 0.3902 - val_accuracy: 0.9217
# Epoch 68/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5785 - accuracy: 0.8579 - val_loss: 0.3839 - val_accuracy: 0.9237
# Epoch 69/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5681 - accuracy: 0.8591 - val_loss: 0.4058 - val_accuracy: 0.9148
# Epoch 70/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5740 - accuracy: 0.8574 - val_loss: 0.4039 - val_accuracy: 0.9146
# Epoch 71/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5635 - accuracy: 0.8609 - val_loss: 0.3714 - val_accuracy: 0.9262
# Epoch 72/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5654 - accuracy: 0.8587 - val_loss: 0.3806 - val_accuracy: 0.9221
# Epoch 73/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5650 - accuracy: 0.8600 - val_loss: 0.3866 - val_accuracy: 0.9132
# Epoch 74/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5667 - accuracy: 0.8566 - val_loss: 0.3917 - val_accuracy: 0.9192
# Epoch 75/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5667 - accuracy: 0.8584 - val_loss: 0.3785 - val_accuracy: 0.9236
# Epoch 76/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.5671 - accuracy: 0.8600 - val_loss: 0.3954 - val_accuracy: 0.9172

# %%
# 모델 평가
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss: ", round(test_loss,4), "Test accuracy:", round(test_acc,4))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 15374.5713 - accuracy: 0.5982
# Test loss:  15374.5713 Test accuracy: 0.5982

# %%
# 모델 저장
model.save('mnist_opt_level_03_Adam.h5')

# %%
import matplotlib
import matplotlib.pyplot as plt

fig, loss_ax =  plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
#loss_ax.plot(hist.history['val_loss'], 'g', label='validation loss')
acc_ax.plot(hist.history['accuracy'], 'b', label='train accuracy')
#acc_ax.plot(hist.history['val_accuracy'], 'r', label='validation accuracy')

plt.legend(['train loss', 'train accuracy'])
plt.show()
