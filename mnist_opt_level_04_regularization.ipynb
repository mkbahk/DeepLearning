# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from keras import regularizers

# %%
#하이퍼 파라메터 정의(매개변수들)
EPOCHS = 200
BATCH_SIZE = 128
VERBOSE = 1
NB_CLASSES = 10 #출력갯수 = 숫자의 갯수
N_HIDDEN = 128 
VALIDATION_SPLIT = 0.2 #검증을 위해 남겨둘 훈련 데이타
DROPOUT = 0.3

# %%
# MNIST 데이타셋 로드(MNIST는 숫자만, eMNIST는 숫자+알파벳, 패션MNIST는 옷그림들이 있다)
# X값 훈련용, 테스트 데이터를 각각 60,000개와 10,000개로 나눈다
# 레이블(정답, Y값)에 대한 원핫 인코딩을 자동으로 적용한다
# 아래 데이타셋을 .png 형태의 이미지를 이미 숫자화한 배열형태로 바꾸어 놓은 것이며, .csv형태가 분석 초기 데이타이다.
mnist = keras.datasets.mnist
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

# X_train은 60,000개 행으로 28x28 값을 가진다. 이를 60,000 x 784(28x28)의 행렬형태로 변환한다.
RESHAPED = 784

X_train = X_train.reshape(60000, RESHAPED)
X_test = X_test.reshape(10000, RESHAPED)

X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# 입력을 [0, 1] 사이로 정규화
X_train /= 255.0
X_train /= 255.0

print(X_train.shape[0], 'train samples')
print(X_test.shape[0], 'train samples')

# 레이블을 원한 엔코딩, 그래야 행렬 연산이 가능함
Y_train = tf.keras.utils.to_categorical(Y_train, NB_CLASSES)
Y_test = tf.keras.utils.to_categorical(Y_test, NB_CLASSES)
# Out:
# 60000 train samples
# 10000 train samples

# %%
# 모델 구축(정의)
model = tf.keras.models.Sequential()
model.add(keras.layers.Dense(N_HIDDEN, input_shape=(RESHAPED,), name='input_Dense_layer_1', activation='relu', kernel_regularizer=regularizers.l2(0.01),
                activity_regularizer=regularizers.l1(0.01)))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(N_HIDDEN, name='hidden_Dense_layer_2', activation='relu'))
model.add(keras.layers.Dropout(DROPOUT))
model.add(keras.layers.Dense(NB_CLASSES, name='output_Dense_layer_3', activation='softmax'))

# %%
# 모델 컴파일
model.compile(optimizer='Adam',
             loss='categorical_crossentropy',
             metrics=['accuracy'])

# %%
# 모델 형태 보기
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_Dense_layer_1 (Dense)  (None, 128)               100480
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# hidden_Dense_layer_2 (Dense) (None, 128)               16512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# output_Dense_layer_3 (Dense) (None, 10)                1290
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 훈련
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(patience=15, mode='auto', monitor='val_accuracy')

hist = model.fit(x = X_train, y = Y_train, 
          batch_size = BATCH_SIZE, epochs=EPOCHS,
          verbose=VERBOSE, validation_split=VALIDATION_SPLIT,
          callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 375/375 [==============================] - 1s 3ms/step - loss: 2.4215 - accuracy: 0.1389 - val_loss: 2.1918 - val_accuracy: 0.2211
# Epoch 2/200
# 375/375 [==============================] - 1s 3ms/step - loss: 2.0171 - accuracy: 0.2572 - val_loss: 1.8729 - val_accuracy: 0.3111
# Epoch 3/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.8774 - accuracy: 0.3016 - val_loss: 1.7799 - val_accuracy: 0.3530
# Epoch 4/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.7979 - accuracy: 0.3444 - val_loss: 1.6491 - val_accuracy: 0.4514
# Epoch 5/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.6823 - accuracy: 0.3948 - val_loss: 1.5084 - val_accuracy: 0.4700
# Epoch 6/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5885 - accuracy: 0.4288 - val_loss: 1.4153 - val_accuracy: 0.5414
# Epoch 7/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.5258 - accuracy: 0.4625 - val_loss: 1.3380 - val_accuracy: 0.5876
# Epoch 8/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4589 - accuracy: 0.5015 - val_loss: 1.2784 - val_accuracy: 0.6333
# Epoch 9/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.4076 - accuracy: 0.5293 - val_loss: 1.2141 - val_accuracy: 0.6633
# Epoch 10/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3578 - accuracy: 0.5583 - val_loss: 1.1936 - val_accuracy: 0.6918
# Epoch 11/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.3250 - accuracy: 0.5811 - val_loss: 1.1026 - val_accuracy: 0.7239
# Epoch 12/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2823 - accuracy: 0.6014 - val_loss: 1.0917 - val_accuracy: 0.7333
# Epoch 13/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.2399 - accuracy: 0.6254 - val_loss: 0.9967 - val_accuracy: 0.7735
# Epoch 14/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.1893 - accuracy: 0.6495 - val_loss: 0.9358 - val_accuracy: 0.8052
# Epoch 15/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.1497 - accuracy: 0.6666 - val_loss: 0.9092 - val_accuracy: 0.7971
# Epoch 16/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.1097 - accuracy: 0.6817 - val_loss: 0.8584 - val_accuracy: 0.8202
# Epoch 17/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0790 - accuracy: 0.6924 - val_loss: 0.8248 - val_accuracy: 0.8296
# Epoch 18/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0651 - accuracy: 0.6991 - val_loss: 0.8154 - val_accuracy: 0.8166
# Epoch 19/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0394 - accuracy: 0.7082 - val_loss: 0.7760 - val_accuracy: 0.8437
# Epoch 20/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0222 - accuracy: 0.7152 - val_loss: 0.7664 - val_accuracy: 0.8347
# Epoch 21/200
# 375/375 [==============================] - 1s 3ms/step - loss: 1.0082 - accuracy: 0.7223 - val_loss: 0.7454 - val_accuracy: 0.8419
# Epoch 22/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9959 - accuracy: 0.7255 - val_loss: 0.7283 - val_accuracy: 0.8505
# Epoch 23/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9847 - accuracy: 0.7307 - val_loss: 0.7263 - val_accuracy: 0.8495
# Epoch 24/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9681 - accuracy: 0.7366 - val_loss: 0.7094 - val_accuracy: 0.8570
# Epoch 25/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9540 - accuracy: 0.7403 - val_loss: 0.6872 - val_accuracy: 0.8629
# Epoch 26/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9469 - accuracy: 0.7433 - val_loss: 0.6835 - val_accuracy: 0.8594
# Epoch 27/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9403 - accuracy: 0.7467 - val_loss: 0.6623 - val_accuracy: 0.8675
# Epoch 28/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9258 - accuracy: 0.7502 - val_loss: 0.6798 - val_accuracy: 0.8605
# Epoch 29/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9157 - accuracy: 0.7531 - val_loss: 0.6576 - val_accuracy: 0.8637
# Epoch 30/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.9095 - accuracy: 0.7534 - val_loss: 0.6295 - val_accuracy: 0.8728
# Epoch 31/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8966 - accuracy: 0.7592 - val_loss: 0.6608 - val_accuracy: 0.8585
# Epoch 32/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8938 - accuracy: 0.7624 - val_loss: 0.6168 - val_accuracy: 0.8780
# Epoch 33/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8747 - accuracy: 0.7684 - val_loss: 0.6155 - val_accuracy: 0.8778
# Epoch 34/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8739 - accuracy: 0.7660 - val_loss: 0.5926 - val_accuracy: 0.8789
# Epoch 35/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8742 - accuracy: 0.7682 - val_loss: 0.6092 - val_accuracy: 0.8789
# Epoch 36/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8523 - accuracy: 0.7742 - val_loss: 0.6055 - val_accuracy: 0.8721
# Epoch 37/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8463 - accuracy: 0.7775 - val_loss: 0.5748 - val_accuracy: 0.8803
# Epoch 38/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8423 - accuracy: 0.7772 - val_loss: 0.5643 - val_accuracy: 0.8868
# Epoch 39/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8312 - accuracy: 0.7804 - val_loss: 0.5676 - val_accuracy: 0.8771
# Epoch 40/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8334 - accuracy: 0.7790 - val_loss: 0.5584 - val_accuracy: 0.8857
# Epoch 41/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8190 - accuracy: 0.7844 - val_loss: 0.5585 - val_accuracy: 0.8824
# Epoch 42/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8169 - accuracy: 0.7835 - val_loss: 0.5476 - val_accuracy: 0.8866
# Epoch 43/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8087 - accuracy: 0.7855 - val_loss: 0.5459 - val_accuracy: 0.8838
# Epoch 44/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8029 - accuracy: 0.7870 - val_loss: 0.5266 - val_accuracy: 0.8896
# Epoch 45/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7957 - accuracy: 0.7913 - val_loss: 0.5479 - val_accuracy: 0.8846
# Epoch 46/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.8029 - accuracy: 0.7869 - val_loss: 0.5409 - val_accuracy: 0.8867
# Epoch 47/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7884 - accuracy: 0.7900 - val_loss: 0.5229 - val_accuracy: 0.8958
# Epoch 48/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7845 - accuracy: 0.7942 - val_loss: 0.5235 - val_accuracy: 0.8890
# Epoch 49/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7769 - accuracy: 0.7955 - val_loss: 0.5106 - val_accuracy: 0.8953
# Epoch 50/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7820 - accuracy: 0.7920 - val_loss: 0.5515 - val_accuracy: 0.8779
# Epoch 51/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7866 - accuracy: 0.7918 - val_loss: 0.5064 - val_accuracy: 0.8945
# Epoch 52/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7742 - accuracy: 0.7965 - val_loss: 0.5142 - val_accuracy: 0.8917
# Epoch 53/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7738 - accuracy: 0.7959 - val_loss: 0.5270 - val_accuracy: 0.8846
# Epoch 54/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7679 - accuracy: 0.7993 - val_loss: 0.4966 - val_accuracy: 0.8982
# Epoch 55/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7718 - accuracy: 0.7951 - val_loss: 0.4931 - val_accuracy: 0.8946
# Epoch 56/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7618 - accuracy: 0.7998 - val_loss: 0.4901 - val_accuracy: 0.8971
# Epoch 57/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7619 - accuracy: 0.8001 - val_loss: 0.4924 - val_accuracy: 0.8988
# Epoch 58/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7542 - accuracy: 0.8024 - val_loss: 0.4979 - val_accuracy: 0.8893
# Epoch 59/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7590 - accuracy: 0.7992 - val_loss: 0.4842 - val_accuracy: 0.8950
# Epoch 60/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7603 - accuracy: 0.7991 - val_loss: 0.4929 - val_accuracy: 0.8956
# Epoch 61/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7494 - accuracy: 0.8009 - val_loss: 0.4981 - val_accuracy: 0.8901
# Epoch 62/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7441 - accuracy: 0.8046 - val_loss: 0.4744 - val_accuracy: 0.8987
# Epoch 63/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7492 - accuracy: 0.8009 - val_loss: 0.4777 - val_accuracy: 0.9010
# Epoch 64/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7537 - accuracy: 0.8014 - val_loss: 0.5087 - val_accuracy: 0.8891
# Epoch 65/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7481 - accuracy: 0.8036 - val_loss: 0.5060 - val_accuracy: 0.8895
# Epoch 66/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7429 - accuracy: 0.8037 - val_loss: 0.4729 - val_accuracy: 0.8959
# Epoch 67/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7385 - accuracy: 0.8051 - val_loss: 0.4932 - val_accuracy: 0.8909
# Epoch 68/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7397 - accuracy: 0.8045 - val_loss: 0.4732 - val_accuracy: 0.8959
# Epoch 69/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7415 - accuracy: 0.8024 - val_loss: 0.4826 - val_accuracy: 0.8949
# Epoch 70/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7424 - accuracy: 0.8026 - val_loss: 0.4770 - val_accuracy: 0.8981
# Epoch 71/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7323 - accuracy: 0.8073 - val_loss: 0.4721 - val_accuracy: 0.9008
# Epoch 72/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7397 - accuracy: 0.8027 - val_loss: 0.4572 - val_accuracy: 0.9019
# Epoch 73/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7362 - accuracy: 0.8060 - val_loss: 0.4866 - val_accuracy: 0.8961
# Epoch 74/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7396 - accuracy: 0.8050 - val_loss: 0.4843 - val_accuracy: 0.8946
# Epoch 75/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7349 - accuracy: 0.8062 - val_loss: 0.4792 - val_accuracy: 0.8985
# Epoch 76/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7360 - accuracy: 0.8039 - val_loss: 0.4579 - val_accuracy: 0.9062
# Epoch 77/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7324 - accuracy: 0.8068 - val_loss: 0.4630 - val_accuracy: 0.8998
# Epoch 78/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7233 - accuracy: 0.8079 - val_loss: 0.4598 - val_accuracy: 0.9007
# Epoch 79/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7265 - accuracy: 0.8084 - val_loss: 0.4806 - val_accuracy: 0.8896
# Epoch 80/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7227 - accuracy: 0.8099 - val_loss: 0.4567 - val_accuracy: 0.8980
# Epoch 81/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7201 - accuracy: 0.8081 - val_loss: 0.4644 - val_accuracy: 0.9029
# Epoch 82/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7312 - accuracy: 0.8063 - val_loss: 0.4463 - val_accuracy: 0.9060
# Epoch 83/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7251 - accuracy: 0.8100 - val_loss: 0.4368 - val_accuracy: 0.9103
# Epoch 84/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7241 - accuracy: 0.8062 - val_loss: 0.4622 - val_accuracy: 0.8996
# Epoch 85/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7239 - accuracy: 0.8090 - val_loss: 0.4577 - val_accuracy: 0.9020
# Epoch 86/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7246 - accuracy: 0.8071 - val_loss: 0.4592 - val_accuracy: 0.9057
# Epoch 87/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7202 - accuracy: 0.8097 - val_loss: 0.4506 - val_accuracy: 0.9032
# Epoch 88/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7173 - accuracy: 0.8130 - val_loss: 0.4411 - val_accuracy: 0.9072
# Epoch 89/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7142 - accuracy: 0.8116 - val_loss: 0.4653 - val_accuracy: 0.8934
# Epoch 90/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7179 - accuracy: 0.8090 - val_loss: 0.4509 - val_accuracy: 0.9023
# Epoch 91/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7156 - accuracy: 0.8107 - val_loss: 0.4703 - val_accuracy: 0.8933
# Epoch 92/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7275 - accuracy: 0.8071 - val_loss: 0.4522 - val_accuracy: 0.9078
# Epoch 93/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7130 - accuracy: 0.8123 - val_loss: 0.4465 - val_accuracy: 0.9057
# Epoch 94/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7151 - accuracy: 0.8109 - val_loss: 0.4333 - val_accuracy: 0.9074
# Epoch 95/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7068 - accuracy: 0.8154 - val_loss: 0.4525 - val_accuracy: 0.9018
# Epoch 96/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7044 - accuracy: 0.8144 - val_loss: 0.4478 - val_accuracy: 0.8978
# Epoch 97/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7192 - accuracy: 0.8098 - val_loss: 0.4493 - val_accuracy: 0.9044
# Epoch 98/200
# 375/375 [==============================] - 1s 3ms/step - loss: 0.7144 - accuracy: 0.8117 - val_loss: 0.4505 - val_accuracy: 0.9048

# %%
# 모델 평가
test_loss, test_acc = model.evaluate(X_test, Y_test)
print("Test loss: ", round(test_loss,4), "Test accuracy:", round(test_acc,4))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 22272.1836 - accuracy: 0.5793
# Test loss:  22272.1836 Test accuracy: 0.5793

# %%
# 모델 저장
model.save('emnist_opt_level_04_regularization.h5')

# %%
import matplotlib
import matplotlib.pyplot as plt

fig, loss_ax =  plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='train loss')
#loss_ax.plot(hist.history['val_loss'], 'g', label='validation loss')
acc_ax.plot(hist.history['accuracy'], 'b', label='train accuracy')
#acc_ax.plot(hist.history['val_accuracy'], 'r', label='validation accuracy')

plt.legend(['train loss', 'train accuracy'])
plt.show()
