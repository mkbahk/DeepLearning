# %% [markdown]
# 기본 모듈 인포트

# %%
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# 데이타 준비하기

# %%
# 모델 / 데이타셋 파라메터
num_classes = 10
input_shape = (28, 28, 1)

#데이타셋 로드하고 훈련과 테스트셋으로 분리
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# [0,1] 범위로 이미지 크기변경
x_train = x_train.astype("float32") / 255
x_test = x_test.astype("float32") / 255

#shape이 (28, 28, 1)인지 확인하기
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

# class vector들을 binary class matrices 들로 변환하기
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test =  keras.utils.to_categorical(y_test, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# 데이타 타입 확인하기

# %%
print("x_train shape:", x_train.shape)
print("y_train shape:", y_train.shape)
print("x_test shape:", x_test.shape)
print("y_test shape:", y_test.shape)

print(x_train.shape[0], "훈련 샘플들")
print(x_train.shape[1], "훈련 샘플들")
print(x_train.shape[2], "훈련 샘플들")
print(x_train.shape[3], "훈련 샘플들")

print(x_test.shape[0], "테스트 샘플들")
# Out:
# x_train shape: (60000, 28, 28, 1)
# y_train shape: (60000, 10)
# x_test shape: (10000, 28, 28, 1)
# y_test shape: (10000, 10)
# 60000 훈련 샘플들
# 28 훈련 샘플들
# 28 훈련 샘플들
# 1 훈련 샘플들
# 10000 테스트 샘플들

# %% [markdown]
# 모델 만들기

# %%
model = keras.Sequential(
    [
     keras.Input(shape=input_shape),
     layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
     layers.MaxPooling2D(pool_size=(2, 2)),
     layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
     layers.MaxPooling2D(pool_size=(2, 2)),
     layers.Flatten(),
     layers.Dropout(0.5),
     layers.Dense(num_classes, activation="softmax") 
    ]
)

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                16010
# =================================================================
# Total params: 34,826
# Trainable params: 34,826
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 모델 훈련

# %%
batch_size = 128
epochs = 15

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
hist = model.fit(x=x_train, y=y_train, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# Out:
# Epoch 1/15
# 422/422 [==============================] - 39s 93ms/step - loss: 0.3768 - accuracy: 0.8872 - val_loss: 0.0862 - val_accuracy: 0.9763
# Epoch 2/15
# 422/422 [==============================] - 39s 93ms/step - loss: 0.1146 - accuracy: 0.9652 - val_loss: 0.0607 - val_accuracy: 0.9830
# Epoch 3/15
# 422/422 [==============================] - 39s 93ms/step - loss: 0.0864 - accuracy: 0.9735 - val_loss: 0.0520 - val_accuracy: 0.9860
# Epoch 4/15
# 422/422 [==============================] - 39s 92ms/step - loss: 0.0711 - accuracy: 0.9778 - val_loss: 0.0399 - val_accuracy: 0.9902
# Epoch 5/15
# 422/422 [==============================] - 39s 92ms/step - loss: 0.0612 - accuracy: 0.9806 - val_loss: 0.0392 - val_accuracy: 0.9888
# Epoch 6/15
# 422/422 [==============================] - 39s 92ms/step - loss: 0.0563 - accuracy: 0.9826 - val_loss: 0.0344 - val_accuracy: 0.9908
# Epoch 7/15
# 422/422 [==============================] - 39s 93ms/step - loss: 0.0511 - accuracy: 0.9841 - val_loss: 0.0359 - val_accuracy: 0.9902
# Epoch 8/15
# 422/422 [==============================] - 39s 92ms/step - loss: 0.0483 - accuracy: 0.9847 - val_loss: 0.0344 - val_accuracy: 0.9907
# Epoch 9/15
# 422/422 [==============================] - 43s 102ms/step - loss: 0.0459 - accuracy: 0.9853 - val_loss: 0.0314 - val_accuracy: 0.9915
# Epoch 10/15
# 422/422 [==============================] - 39s 92ms/step - loss: 0.0419 - accuracy: 0.9866 - val_loss: 0.0316 - val_accuracy: 0.9920
# Epoch 11/15
# 422/422 [==============================] - 39s 92ms/step - loss: 0.0390 - accuracy: 0.9879 - val_loss: 0.0298 - val_accuracy: 0.9923
# Epoch 12/15
# 422/422 [==============================] - 39s 93ms/step - loss: 0.0393 - accuracy: 0.9872 - val_loss: 0.0284 - val_accuracy: 0.9928
# Epoch 13/15
# 422/422 [==============================] - 39s 93ms/step - loss: 0.0360 - accuracy: 0.9889 - val_loss: 0.0288 - val_accuracy: 0.9927
# Epoch 14/15
# 422/422 [==============================] - 39s 93ms/step - loss: 0.0352 - accuracy: 0.9886 - val_loss: 0.0304 - val_accuracy: 0.9917
# Epoch 15/15
# 422/422 [==============================] - 39s 94ms/step - loss: 0.0324 - accuracy: 0.9895 - val_loss: 0.0309 - val_accuracy: 0.9915

# %% [markdown]
# 모델 평가

# %%
score =  model.evaluate(x=x_test, y=y_test, verbose=0)
print("테스트 손실값:", score[0])
print("테스트 정확도:", score[1])
# Out:
# 테스트 손실값: 0.02807612530887127
# 테스트 정확도: 0.9908000230789185

# %% [markdown]
# 학습과정 그래프 그리기

# %%
import matplotlib
import matplotlib.pyplot as plt

fig, loss_ax =  plt.subplots()
acc_ax = loss_ax.twinx()

loss_ax.plot(hist.history['loss'], 'y', label='훈련손실')
loss_ax.plot(hist.history['val_loss'], 'g', label='검증손실')
acc_ax.plot(hist.history['acc'], 'b', label='훈련 정확도')
acc_ax.plot(hist.history['val_acc'], 'r', label='검증정확도')

plt.legend(['train acc', 'validation acc'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-f4d561e05d1d> in <module>()
#       7 loss_ax.plot(hist.history['loss'], 'y', label='train loss')
#       8 loss_ax.plot(hist.history['val_loss'], 'g', label='validation loss')
# ----> 9 acc_ax.plot(hist.history['acc'], 'b', label='train acc')
#      10 acc_ax.plot(hist.history['val_acc'], 'r', label='validation acc')
#      11
#
# KeyError: 'acc'
