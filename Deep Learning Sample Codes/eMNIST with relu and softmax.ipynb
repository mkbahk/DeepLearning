# %% [markdown]
# # 0. 모듈 인포트

# %%
from tensorflow import keras
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation

# %% [markdown]
# #1. 데이타셋 준비하기

# %%
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
X_train = X_train.reshape(60000, 28*28).astype('float32') / 255.0
X_test = X_test.reshape(10000, 28*28).astype('float32') / 255.0
Y_train = np_utils.to_categorical(Y_train)
Y_test = np_utils.to_categorical(Y_test)

# %% [markdown]
# Overfitting을 찾아보기 위해 Traing Data세트중에서 Validation Set으로 추가분할

# %%
X_val = X_train[50000:60000]
Y_val = Y_train[50000:60000]
X_train = X_train[0:50000]
Y_train = Y_train[0:50000]

# %% [markdown]
# # 2. 모델 구성하기

# %%
model = Sequential()
model.add(Dense(64, input_dim=28*28, activation='relu', kernel_initializer='glorot_uniform', bias_initializer='zeros'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# #3. 모델 엮기

# %%
model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.1), loss='categorical_crossentropy', metrics='accuracy')
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 64)                50240
# _________________________________________________________________
# dense_13 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dense_14 (Dense)             (None, 16)                528
# _________________________________________________________________
# dense_15 (Dense)             (None, 10)                170
# =================================================================
# Total params: 53,018
# Trainable params: 53,018
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 4. 학습Training

# %% [markdown]
# 검증셋은 overfitting을 보기위해 학습 중단시기를 결정하기 위해 필요

# %%
model.fit(x=X_train, y=Y_train, epochs=10, batch_size=8, validation_data=(X_val, Y_val) )
# Out:
# Epoch 1/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.3286 - accuracy: 0.9011 - val_loss: 0.1610 - val_accuracy: 0.9541
# Epoch 2/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.1714 - accuracy: 0.9502 - val_loss: 0.1416 - val_accuracy: 0.9624
# Epoch 3/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.1379 - accuracy: 0.9605 - val_loss: 0.1372 - val_accuracy: 0.9612
# Epoch 4/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.1155 - accuracy: 0.9669 - val_loss: 0.1550 - val_accuracy: 0.9585
# Epoch 5/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.1053 - accuracy: 0.9691 - val_loss: 0.1233 - val_accuracy: 0.9681
# Epoch 6/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.0950 - accuracy: 0.9729 - val_loss: 0.1317 - val_accuracy: 0.9671
# Epoch 7/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.0833 - accuracy: 0.9763 - val_loss: 0.1229 - val_accuracy: 0.9715
# Epoch 8/10
# 6250/6250 [==============================] - 8s 1ms/step - loss: 0.0790 - accuracy: 0.9777 - val_loss: 0.1684 - val_accuracy: 0.9619
# Epoch 9/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.0741 - accuracy: 0.9796 - val_loss: 0.1492 - val_accuracy: 0.9689
# Epoch 10/10
# 6250/6250 [==============================] - 7s 1ms/step - loss: 0.0699 - accuracy: 0.9805 - val_loss: 0.1429 - val_accuracy: 0.9682

# %% [markdown]
# # 5. 추론Inference

# %%
loss_and_metrics = model.evaluate(x=X_test, y=Y_test, batch_size=8)
print("loss_and_metrics : " + str(loss_and_metrics))
# Out:
# 1250/1250 [==============================] - 1s 771us/step - loss: 0.1360 - accuracy: 0.9658
# loss_and_metrics : [0.13597142696380615, 0.9657999873161316]
