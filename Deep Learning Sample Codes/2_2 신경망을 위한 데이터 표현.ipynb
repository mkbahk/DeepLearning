# %% [markdown]
# 스칼라(0D텐서)

# %%
import numpy as np

# %%
x = np.array(12)

# %%
x
# Out:
# array(12)

# %%
x.ndim
# Out:
# 0

# %% [markdown]
# 벡터(1D텐서)

# %%
x = np.array([12, 3, 6, 14, 7])
# Out:
# 1

# %%
x
# Out:
# array([12,  3,  6, 14,  7])

# %%
x.ndim
# Out:
# 1

# %% [markdown]
# 행렬(2D텐서)

# %%
x = np.array([[5, 78, 2, 34, 0],
              [6, 79, 3, 35, 1],
              [7, 80, 4, 36,2]])

# %%
x
# Out:
# array([[ 5, 78,  2, 34,  0],
#        [ 6, 79,  3, 35,  1],
#        [ 7, 80,  4, 36,  2]])

# %%
x.ndim
# Out:
# 2

# %% [markdown]
# 3D 텐와 고차원 텐서

# %%
x = np.array([
              [[5, 78, 3, 34, 0],
               [6, 79, 3, 36,1],
                [7, 80, 4, 36, 2]],
              
               [[5, 78, 2, 34, 0],
                [6, 79, 3, 35, 1],
                [7, 80, 4, 34, 2]],
              
               [[5, 78, 2, 34, 0],
                [6, 79, 3, 35, 1],
                [7, 80, 4, 36, 7]]
               ])

# %%
x
# Out:
# array([[[ 5, 78,  3, 34,  0],
#         [ 6, 79,  3, 36,  1],
#         [ 7, 80,  4, 36,  2]],
#
#        [[ 5, 78,  2, 34,  0],
#         [ 6, 79,  3, 35,  1],
#         [ 7, 80,  4, 34,  2]],
#
#        [[ 5, 78,  2, 34,  0],
#         [ 6, 79,  3, 35,  1],
#         [ 7, 80,  4, 36,  7]]])

# %%
x.ndim
# Out:
# 3
